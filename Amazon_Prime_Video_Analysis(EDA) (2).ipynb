# %% [markdown]
# # **Project Name**    - Amazon-Prime-Video-Analysis
#
# ---

# %% [markdown]
# ##### **Project Type**    - Amazon-prime-video

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on performing Exploratory Data Analysis (EDA) on the Amazon Prime Video dataset to extract meaningful insights about content distribution, user ratings, and popularity trends. The analysis includes data cleaning, handling missing values, and transforming data for better usability. Various visualizations have been created using Python libraries such as Pandas, Matplotlib, and Seaborn to identify patterns and trends in the dataset. Key insights include the distribution of movies and TV shows, trends over the years, top-rated content based on IMDb scores, and relationships between important features like popularity, votes, and ratings. This project demonstrates strong analytical thinking, data manipulation skills, and the ability to communicate insights effectively using visualizations. After merging two datasets contains rows 125254 and column 14.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/kareenagola97-ui/Amazon-Prime-EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# Content Diversity: What genres and categories dominate the platform?
#
# Regional Availability: How does content distribution vary across different regions?
# Trends Over Time: How has Amazon Prime’s content library evolved?
#
# IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here. The objective of this project is to perform Exploratory Data Analysis (EDA) on the Amazon Prime Video dataset to uncover meaningful insights related to content distribution, ratings, popularity, genres, and viewing trends. The analysis helps businesses understand customer preferences, improve content strategies, and support data-driven decision-making.This also help to
# analysis the customer interest so they support to help the making decision which movies aor shows the most viewed.

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
titles_df=pd.read_csv('/content/titles.csv.zip')
credits_df=pd.read_csv('/content/credits.csv.zip')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
print(f'first view of titles dataset:',titles_df.head())
print(f'last view of titles dataset:',titles_df.tail())
print(f'first view of credits dataset:',credits_df.head())
print(f'last view of credits dataset:',credits_df.tail())
# Out:
# first view of titles dataset:         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
print(f'Number of rows titles datasets:',titles_df.shape[0])
print(f'Number of columns titles datasets:',titles_df.shape[1])
print(f"Number of ries credits datasets:",credits_df.shape[0])
print(f"Number of columns credits datasets:",credits_df.shape[1])
# Out:
# Number of rows titles datasets: 9871
# Number of columns titles datasets: 15
# Number of ries credits datasets: 124235
# Number of columns credits datasets: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print(f'titles dataset info:',titles_df.info())
print(f'credits dataset info:',credits_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f'titles dataset duplicate values:',titles_df.duplicated().sum())
print(f'credits dataset duplicate values:',credits_df.duplicated().sum())
# Out:
# titles dataset duplicate values: 3
# credits dataset duplicate values: 56

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values_titles=titles_df.isnull().sum()
missing_values_credits=credits_df.isnull().sum()
print(f'titles dataset missing values:',missing_values_titles)
print(f'credits dataset missing values:',missing_values_credits)
# Out:
# titles dataset missing values: id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64
# credits dataset missing values: person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(8,4))
sns.heatmap(titles_df.isnull(),yticklabels=False,cbar=False,cmap='coolwarm')
plt.title('Missing values in titles dataset')
plt.show()
plt.figure(figsize=(8,4))
sns.heatmap(credits_df.isnull(),yticklabels=False,cbar=False,cmap='viridis',annot=True)
plt.title('Missing values in credits dataset')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here:This datsets contains structued data about Amazon Prime content.It includes the two datasets. 1.titles datasets : they contain the content details. 2.credits datasets: they contain the actors or directors. The titles contain a more null_values  in age_certfication and seasons .The credits contain a more null_vales in charactor.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(f'titles dataset columns:',titles_df.columns)
print(f'credits dataset columns:',credits_df.columns)
# Out:
# titles dataset columns: Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')
# credits dataset columns: Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
print(f'titles dataset describe:',titles_df.describe())
print(f'credits dataset describe:',credits_df.describe())
# Out:
# titles dataset describe:        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here:
# *** The titles have Variables***
#
# id: The title ID on JustWatch.
#
# title: The name of the title.
#
# show_type: TV show or movie.
#
# description: A brief description.
#
# release_year: The release year.
#
# age_certification: The age certification.
#
# runtime: The length of the episode (SHOW) or movie.
#
# genres: A list of genres.
#
# production_countries: A list of countries that produced the title.
#
# seasons: Number of seasons if it's a SHOW.
#
# imdb_id: The title ID on IMDB.
#
# imdb_score: Score on IMDB.
#
# imdb_votes: Votes on IMDB.
#
# tmdb_popularity: Popularity on TMDB.
#
# tmdb_score: Score on TMDB.
#
# *** The credits contain has variables***
#
# person_ID: The person ID on JustWatch.
#
# id: The title ID on JustWatch.
#
# name: The actor or director's name.
#
# character_name: The character name.
#
# role: ACTOR or DIRECTOR.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(f'titles dataset unique values:',titles_df.nunique())
print(f'credits dataset unique values:',credits_df.nunique())
# Out:
# titles dataset unique values: id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64
# credits dataset unique values: person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# handling missing value
titles_df['description']=titles_df['description'].fillna('no description')
titles_df['age_certification']=titles_df['age_certification'].fillna('no certification')
titles_df['seasons']=titles_df['seasons'].fillna(0)
titles_df['imdb_score']=titles_df['imdb_score'].fillna(titles_df['imdb_score'].median())
titles_df['imdb_votes']=titles_df['imdb_votes'].fillna(titles_df['imdb_votes'].median())
titles_df['tmdb_popularity']=titles_df['tmdb_popularity'].fillna(titles_df['tmdb_popularity'].mean())
titles_df['tmdb_score']=titles_df['tmdb_score'].fillna(titles_df['tmdb_score'].mean())
credits_df['character']=credits_df['character'].fillna('no character')
# drop the duplicates
titles_df=titles_df.drop_duplicates()
# dopna the colums
titles_df=titles_df.dropna(subset=['age_certification'])
titles_df=titles_df.dropna(subset=['seasons'])
credits_df=credits_df.dropna(subset=['character'])
# Rename the colums
titles_df.rename(columns={'release_year':'year'},inplace=True)
credits_df.rename(columns={'role':'Role'},inplace=True)
# merging the datsets
merged_df=pd.merge(titles_df,credits_df,on='id',how='left')
merged_df=merged_df.drop_duplicates(subset=['title'])
top_popular=merged_df.sort_values(by='tmdb_popularity',ascending=False).head(10)['title']
high_rated_movies=merged_df[merged_df['imdb_score']>7].head(10)['title']
year_with_most_content=merged_df['year'].value_counts().idxmax()
yearly_distribution=merged_df['year'].value_counts().sort_index().tail()
content_count=merged_df.groupby('type')['id'].count()
avg_rating=merged_df.groupby('type')['imdb_score'].mean()
avg_score=merged_df.groupby('type')['tmdb_score'].mean()
top10_genres=merged_df['genres'].value_counts().head(10)
most_countires_content=merged_df['production_countries'].value_counts().head(10)
top_actors=merged_df.groupby('name')['id'].count().sort_values(ascending=False).head(10)
yearly_type_distribution=merged_df.groupby('year')['type'].value_counts().tail(10)
rating_year=merged_df.groupby('year')['imdb_score'].mean()
print(f'top popular movies:',top_popular)
print(f'high rated movies:',high_rated_movies)
print(f'year with most content:',year_with_most_content)
print(f'yearly distribution:',yearly_distribution)
print(f'content count:',content_count)
print(f'avg rating:',avg_rating)
print(f'avg score:',avg_score)
print(f'top10 genres:',top10_genres)
print(f'most countires content:',most_countires_content)
print(f'top actors:',top_actors)
print(f'yearly type distribution:',yearly_type_distribution)
print(f'rating year:',rating_year)
# Out:
# top popular movies: 116620                   All the Old Knives
# 118564                               Harina
# 118555                    The eighth clause
# 117205    Hotel Transylvania: Transformania
# 100937                   Sonic the Hedgehog
# 119313                      Queen of Spades
# 118123                              Meander
# 64995                                 Suits
# 77989                      Better Call Saul
# 70472                               Vikings
# Name: title, dtype: object
# high rated movies: 0                                     The Three Stooges
# 3                                           The General
# 27                          The Best Years of Our Lives
# 58                                      His Girl Friday
# 94                                    In a Lonely Place
# 114                                          Stagecoach
# 178                               It's a Wonderful Life
# 293                                              Detour
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.I performed data cleaning by handling missing values using mean, median, and placeholder methods, removed duplicates, and corrected data types. I also did feature engineering and merged datasets. Additionally, I used filtering, grouping, and aggregation to analyze the data.
# 👉 From this, I found that content production has increased over time, certain genres dominate, and there is a positive relationship between popularity and user engagement, though it does not always reflect higher ratings.I noticed
# the movies and shows has increased the time but 2022 they shows decreased but not a affected the rating.Also I noticed that US country has more realese and
# mostly loved the drama.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# Univariate

# %%
# Chart - 1 visualization code
merged_df['type'].value_counts().plot(kind='pie',autopct='%1.1f%%',explode=[0.1,0.2],shadow=True,startangle=90,figsize=(10,6))
plt.title('Distribution of Content Types')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A pie chart was chosen because it is effective for showing the proportion and percentage distribution of categorical data.It heps tje easily compare the share of movies and shows available in amazon prime video.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here. Around 86 % of the content of Movies and 14 % of Tv shows .This shows that Amzzon Prime video focuses more on movie-based entertainment content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here. Yes,the insights can help create the positive business impact the understanding content of distribution and also shows that movie has more content then Tv shows .Also give the idea to increasing the Tv shows and web series so people more engage the long time.
#
# A possible negative impact is that having fewer Tv shows may reduce the long-term viewer engagement because users often spend more time to episodic content.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
sns.set_style('whitegrid')
plt.figure(figsize=(8,5))
sns.histplot(merged_df['imdb_score'],bins=10,kde=True)
plt.title('Distribution of IMDB Scores')
plt.xlabel('IMDB Score')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A histogram was chosen because it is useful for understanding the distribution and frequency of numerical data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.1. Most IMDB scores are concentrated in the medium to high rating range.
#
# 2. A  large number of movies and shows have rating between 5 and 6,indicating well content on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here. Yes,these insights can help Amazon Prime Video understand the quailty and audience reception of its content.
#
# A possible negative impact is the low-rated content may reduce viewer trust.

# %% [markdown]
# Chart -3

# %%
# Chart - 3 visualization code
sns.set_style('darkgrid')
merged_df['tmdb_score'].plot(kind='hist',color='red')
plt.title('Distribution of TMDB Scores')
plt.xlabel('TMDB Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer . A histogram was used to understand the distribution of TMDB score and identify the common rating patterns in the datasets.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here . Most conent has TMDB score between 5 ans 8.
# The platform mainly contains average to high rated content. Very few titles have extemely low or high scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes,the insights can create a positive business impact by helping Amazon Prime video understand audience preference and promote highly rated content.Incrasing the quality content can improve the viewer .
#
# A negative is low rated content so incrasing the users interest .

# %% [markdown]
# Chart -4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10,6))
merged_df['genres']=merged_df['genres'].str.replace('[','').str.replace(']','')
top10_genres=merged_df['genres'].value_counts().head(10)
sns.barplot(x=top10_genres.values,y=top10_genres.index,palette='pastel')
plt.title('Top 10 Genres')
# Out:
# /tmp/ipykernel_3571/2336165936.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top10_genres.values,y=top10_genres.index,palette='pastel')
# Text(0.5, 1.0, 'Top 10 Genres')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A bar chart shows top 10 genre.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here . Some genres are more often popular and frequently available than others.
# . The top genres dominate the platform's content library .This helps identify audience preference and trading genrs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here. Yes , Popular genres help Amazon Prime video attract more viewer ,imporve customer statisfaction and increase subscriptions by recommending and producing content that audiences prefer.
#
# A negative impact focusing too much on only few popular genres may reduce content diversity ans also interest.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.style.use('ggplot')
plt.figure(figsize=(10,4))
plt.plot(merged_df['year'].value_counts().sort_index())
plt.title('Distribution of Year')
plt.xlabel('Year')
plt.title('Distribution of Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A line chart was used because it is effective for showing the trend and change in content releases over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here . The number of content releases has increased over the years. Recent years has no such growth but last years grow because of the some series and movies have great content and also quality grow.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes ,Increasing content over the year can attract more viewers,improve engagement and increase subscripton.
# Rapid growth in content without maintaining quality may reduce customer statisfaction and platform trust.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
sns.scatterplot(x='tmdb_popularity',y='imdb_score',hue='type',data=merged_df)
plt.title('IMDB Score vs. TMDB Popularity')
plt.xlabel('TMDB Popularity')
plt.ylabel('IMDB Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.  A scatter plot was used to understand the relationship between TMDB popularity and IMDB score  and hue helps to comapare the Movies and Tv shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## Answer Here .
# . Content with higher popularity generally has higher IMDB scores.
#
# . Movies and Tv shows show different rating and popularity.
#
# . Most content is concentrated in the medium popularity and rating range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes ,these insights help to identify popular and highly rated content for better recommendations and content strategies.
#
# Low-rated but highly promoted content may reduce viwer statsification
# and affect the trust.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
merged_df['production_countries']=merged_df['production_countries'].str.replace('[','').str.replace(']','')
top_10_country_production=merged_df['production_countries'].value_counts().head(10)
plt.figure(figsize=(10,4))
sns.barplot(x=top_10_country_production.values,y=top_10_country_production.index,palette='pastel')
plt.title('Top 10 Countries with Most Production')
plt.xlabel('Count')
plt.ylabel('Country')
plt.show()
# Out:
# /tmp/ipykernel_3571/3391875502.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_country_production.values,y=top_10_country_production.index,palette='pastel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A barplot chart was used because it clearly compares the top 10 production countries based on the number of movies and tv shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here .
# . Some country produced more content than others .The top countries dominate Amazon prime video's content library.
#
# . this shows the major content producing regions on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes , they understanding top production countries helps Amazon Prime Video focus on strong markets ,improve regional recommendations.
#
# Negative impact the Overdependence on content from a few countries may reduce  regional diversity and limit audience interest in markets.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization
top_director=merged_df[merged_df['Role']=='DIRECTOR'].sort_values(by='imdb_score',ascending=False).head(10)
top10_director=top_director[['name','imdb_score']]
px.bar(top10_director,x='imdb_score',y='name',title='Top 10 Directors by IMDB Score',color='imdb_score',labels={'name':'Director','imdb_score':'IMDB Score'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A bar chart was used to compare the top directors based on the number of titles and color also used to represent IMDB score for additional insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here . Some directors have created more content then others .Directors with higher IMDB scores indicate better audience and content quality . The chart helps identify both productive and highly rated directors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes,the positive insights helps the Amazon prime video collaborate with successful and highly rated directors to improve content quality.
#
# Negative the impact the few directors have more content and popular so may reduce the creative diversity and limit opportunity.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
top_rated=merged_df[merged_df['imdb_score']>7]
top_actors=top_rated['name'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_actors.values,y=top_actors.index,palette='pastel')
plt.title('Top 10 Actors with Highest IMDB Ratings')
plt.xlabel('IMDB Rating')
plt.ylabel('Actor')
plt.show()
# Out:
# /tmp/ipykernel_3571/304614125.py:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A barplot was used to compare the actors based on IMDB score also indicate the performance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here . Some acotrs the consistently appear in highly rated content .Actors with higher IMDB score may have stronger audience popularity and performance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes ,these insights helps to promote popular acotrs and invest in content featuring hghlye rated performace to increase viwer engagement.
#
# A negative only focusing highly rated actors may reduce opportunity and talent of new upcoming acotrs.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
sns.lineplot(x='year',y='imdb_score',data=merged_df)
plt.title('IMDB Score Over the Years')
plt.xlabel('Year')
plt.ylabel('IMDB Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.  A line plot was used the trend of IMDB score over the different year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here . IMDB scores vary across different years .Some years show higher average ratings the others .This charts helps identify trends in content quality over the time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here. Yes ,some years the trend rating is good so that is good for business and shwoing the high-quality content.
#
# Negative these insights the recent rating trends is not good for starting trends of years so some improve should be do for increasing the ratings.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10,6))
top10_movies=merged_df[merged_df['type']=='MOVIE'].sort_values(by='imdb_score',ascending=False).head(10)
sns.barplot(x='imdb_score',y='title',data=top10_movies,palette='pastel')
plt.title('Top 10 Movies by IMDB Score')
plt.xlabel('IMDB Score')
plt.ylabel('Movie')
plt.show()
# Out:
# /tmp/ipykernel_3571/880558977.py:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A barplot chart was used to compare the top 10 movies based on IMDB scores and clearly visulize the highest- rated movies .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here. Some movies have high rated IMDb score than others .Highly rated movies indicated the strong apperciation and content quality .This charts shows the most scuessful movies .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here. Yes . The business impact the more investing genre can improve the viewer and more spend the time of favorite genre to more time spend and also subscription incresee.
#
# No such insights that leads the negative impact.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
top10_shows=merged_df[merged_df['type']=='SHOW'].sort_values(by='imdb_score',ascending=False).head(10)
plt.figure(figsize=(10,6))
px.bar(top10_shows,x='imdb_score',y='title',title='Top 10 Shows by IMDB Score',color='imdb_score',color_continuous_scale='viridis',labels={'title':'Show','imdb_score':'IMDB Score'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.  A bar chart was used to compare the top 10 TV shows based on IMDB scores and clearly visualize the highest-rated shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here . Some TV shows have significantly higher IMDB scores than others. Highly rated shows indicate the good quality content and popularity.This charts helps to tell more sucessful shows on Amazon Prime video.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes,highly rated shows great impact to increase the viewer engagement,watch time and suubsription.
#
# Negative impact is like that overfocussing the top rated shows may reduce the visibility for new and less popular shows.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(8,6))
sns.boxplot(x='type',y='runtime',data=merged_df)
plt.title('Distribution of Runtime by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Runtime')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A boxplot was used to compare the runtime distribution of Movies and Tv Shows and identify spread ,median and outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# 1. Movies and Tv shows have different runtime .
# 2. Some content has extrmely high or some low .
# 3. Movies has shows more Outliers(means that are very different to others / unusually high or unusally low values) comparision to Tv shows.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here . Yes,understanding runtime pattern helps Amazon Prime Video Improve the content planning and audience recommendations based on viewer performance.
#
# Negative is very long or inconsistent runtimes may reduce viewer engagement
# and affect user watching experience.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization
corr_matrix=merged_df[['imdb_score','imdb_votes','tmdb_popularity','tmdb_score']].corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# 1+ - strong realtionship
# 0 - weak relationship
# 1- - strong weak realtionship

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A heatmap was used to understand the correalation between numerical features like IMDB score,IMDb votes,TMDb popularity,and TMDb score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# 1. IMDb score and TMDb score show a moderate positive correaltion.
# 2. Some features have weak relationship with each other.
# 3. Higher ratings may slightly relate to higher popularity and votes.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(merged_df[['imdb_score','imdb_votes','tmdb_popularity','runtime','year','type']],hue='type')
plt.suptitle('Pair Plot of Selected Variables',y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. A pair plot was used to visualize relationship between multiple numerical variable at the same time and compare Movies and Tv shows using different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here.
# 1. Some variable show positive relationships with each other.
# 2. Movies and Tv shows have different data distribution patterns.
# 3. Most data points are concentrated  in lower to medium ranges. A few outliers
# are also visible in dataset.

# %% [markdown]
# ### 5. Solution to Business Objective

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here. Amazon Prime Video should focus more on highly rated and popular content to improve viewer engagement and customer satisfaction. The platform can increase content diversity by adding more TV Shows, regional content, and trending genres. Using audience ratings, popularity trends, and viewing patterns can help improve recommendation systems and support better business decisions also help to see the patern of increasing the view.

# %% [markdown]
# ## 6. Recommendations

# %% [markdown]
# 1. Focus more on highly rated and popular content.
# 2. Increase quality TV Shows and regional content for better audience engagement.
# 3. Improve recommendation systems using viewer ratings and popularity trends.
# 4. Collaborate with top actors and directors to attract more viewers.
# 5. Maintain content quality to improve customer satisfaction and subscriptions

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# This project performed Exploratory Data Analysis (EDA) on the Amazon Prime Video dataset to understand content distribution, ratings, popularity, genres, runtime, and yearly trends. The analysis provided meaningful insights that can help improve content strategy, audience engagement, and business growth

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
